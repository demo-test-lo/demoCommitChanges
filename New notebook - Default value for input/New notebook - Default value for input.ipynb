# %% [markdown]
# # Sheet

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'A': np.random.randint(0, 100, 10),
    'B': np.random.randint(0, 100, 10),
    'C': np.random.randint(0, 100, 10),
    'D': np.random.randint(0, 100, 10)
})

df

# %%
value1 = df.at[1, 'B']

# %%
value1 = df.at[1, 'B']
value1_str = str(value1)
value1_str

# %%
text_5 = ""

# %%
print(text_5)

# %%
import datetime

# getting today's date
today = datetime.date.today()

# converting to string
today_str = today.strftime('%Y-%m-%d')
today_str

# %%
text_2 = ""

# %%
value = df.columns[1]

# %%
text_1 = ""

# %%
text_1

# %%
value2=""

# %%
print(value2)

# %%
text_3 = ""

# %%
# New Cell
# define base string
base_string = "I'm a very long string "

# define how many times to repeat
times_to_repeat = 10000

# generate very long string
very_long_string = base_string * times_to_repeat

# print the length of the very long string
print(len(very_long_string))

# %%
text_4 = ""

# %%
dropdown_1 = "text_1"
